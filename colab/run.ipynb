# %%
# STEP 1: Clone repo + install deps + verify GPU
# !cd /content && rm -rf auto-agent-trading && git clone https://github.com/lolokhadim0-source/auto-agent-trading.git && cd auto-agent-trading && git checkout feature/trading-agent-v1 && pip install -q anthropic yfinance ccxt alpaca-py fredapi pandas numpy pyarrow ta python-telegram-bot python-dotenv aiohttp torch && python -c "import torch; print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else \"CPU\"}')" && nvidia-smi | head -5

# %%
# STEP 2: Set YOUR API keys here, then run
import os
os.environ['ANTHROPIC_API_KEY'] = 'YOUR_KEY_HERE'
os.environ['TELEGRAM_BOT_TOKEN'] = 'YOUR_TOKEN_HERE'
os.environ['TELEGRAM_CHAT_ID'] = 'YOUR_CHAT_ID'
os.environ['ALPACA_API_KEY'] = 'YOUR_KEY'
os.environ['ALPACA_SECRET_KEY'] = 'YOUR_SECRET'
os.environ['FRED_API_KEY'] = 'YOUR_KEY'
# !cd /content/auto-agent-trading && python colab_run.py
